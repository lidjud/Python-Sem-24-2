# %% [markdown]
# <a href="https://colab.research.google.com/github/lidjud/Python-Sem-24-2/blob/main/principios_basicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Futuristic Technology Conference Presentation.jpg](data:image/jpeg;base64,...)

# %%
# %%html
# <marquee style='width: 50%; color: blue;'><b>Bienvenidos a su primera clase de programación con Python! 🧁 🦭 ✨ </b></marquee>
# Out:
# <marquee style='width: 50%; color: blue;'><b>Bienvenidos a su primera clase de programación con Python! 🧁 🦭 ✨ </b></marquee>

# %% [markdown]
# # Función print()

# %% [markdown]
# En el contexto de la programación, una **función** es una subrutina o subprograma que permite resolver una tarea especifica.
#
# Iniciaremos con la declaración de una función muy sencilla, la función ```print()```. Esta función imprime el valor que encuentra entre los paréntesis ("texto" o número).
#
# Además de los parentésis, agregamos comilla doble o sencilla para indicar que lo que está entre comillas, no es código.
#
# En la siguiente línea de código, escribe el mensaje Hello world! entre las comillas y ejecútala.

# %% [markdown]
# Declara algunas variables

# %%
print("Hello word!\nHello word\nHello word")

# %%
print("Hello" + "students")

# %%
print("Cada vez que pienso en ti, 🤔 \
mis ojos rompen en llanto; 😢 \
y muy triste me pregunto, 😕 \
¿por qué te quiero tanto? 💘 :Cupid Arrow")

# %% [markdown]
# # Tipos de datos numéricos

# %% [markdown]
# ## Integer

# %%
1 + 1

# %%
a = 4

# %%
type(a)

# %% [markdown]
# ## Floats

# %%
c = 2.1
type(c)

# %% [markdown]
# ## Complex

# %%
a = 1.5 + 0.5j

# %%
a.real

# %%
a.imag

# %%
type(1. + 0j)

# %% [markdown]
# ## Booleans

# %%
3 > 4

# %%
test = (3 > 4)

# %%
test

# %%
type(test)

# %% [markdown]
# # Función input()

# %% [markdown]
# La función ```input()``` es para solicitar al usuario que introduzca algo a través del teclado (entrada estándar).

# %%
input("¿Cual es tu nombre?")

# %% [markdown]
# Observa lo que sucede cuando anidas las funciones ```input()``` y ```print()```.

# %%
print("Hola " + input(" ¿Cuál es tu nombre ?"))

# %% [markdown]
# ## Comentarios en el código

# %% [markdown]
# Puedes escribir comentarios en tu código y que el ordenador lo ignore por completo. Para ello, utiliza el símbolo ```#```.
#
# Esto te permite escribir notas y documentar tu código sin afectar el programa.
#
# También puedes hacer comentarios que se extienden por múltiples líneas encerrando el texto entre ```'''```.
#
# Ejecuta la siguiente línea de código, ¿obtienes alguna salida?

# %%
#Este es un comentario de una solo línea

# %%
"""
Comentario en Python con
múltiples líneas en el
código
"""

print("🚨 Los comentarios no se imprimen")

# %% [markdown]
# Escribir comentarios en nuestro código, nos ayudar a recordar lo que está pasando en él.

# %% [markdown]
# #Condicionales en Python

# %%
year = 1990

# %%
year = year + 36

print( f"El año es {year}..." )

# %%
# if year es 1990
if year == 1990:
    print( "Te dejé un mensaje en la contestadora!" )
# if year es 2026
if year == 2026:
    print( "Te mandé un what's!" )

# %% [markdown]
# ### 😳 ¿Alguna vez has realizado un cuestionario de personalidad en el que hay a respondido a preguntas de varias opciones y descubierto cosas como, por ejemplo, qué tipo de emoji eres?

# %% [markdown]
# Los cuestionarios de Internet son simplemente una serie de preguntas que tienen puntuaciones asociadas a cada posible respuesta y, a continuación, un intervalo de puntuaciones para cada "personalidad".

# %% [markdown]
# Por ejemplo, puede que haya tres preguntas con dos opciones de respuesta cada una:
#
# **¿Cuál es su color favorito?**
#
# 1.   El rojo (10 puntos)
#
# 2.   El verde (4 puntos)
#
# **¿Cuál es su comida favorita?**
#
# 1.   Las patatas fritas (6 puntos)
#
# 2.   El helado (5 puntos)
#
#
# En este caso, habría estos posibles resultados:
#
#
# *   rojo/patatas fritas: 16 puntos
# *   rojo/helado: 15 puntos
# *   verde/patatas fritas: 10 puntos
# *   verde/helado: 9 puntos
#
#
# Y quizás tenga tres posibilidades de personalidad:
#
#
# *   Menos de 10 puntos: es agradable e inteligente.
# *   10-14 puntos: es una persona apasionada e intensa.
# *   Más de 15 puntos: es una persona compasiva y obstinada.

# %% [markdown]
# ***Realiza tu propio cuestionario***:  "¿Cuál es su personaje de superdetective?" 🕶

# %%
# realiza la pregunta
activity = input( "Qué te gusta hacer en tus tardes libres?\n(A) Leer un libro\n(B) Ir a alguna fiesta\n" )

# print out which activity they chose
print( f"Eligiste {activity}.")

# %%
# realiza la pregunta
activity = input( "Qué te gusta hacer en tus tardes libres?\n(A) Leer un libro\n(B) Ir a alguna fiesta\n" )

# print out which activity they chose
print( f"Eligiste {activity}.")

if activity == "A":
    print( "Es una buena opción!" )
if activity == "B":
    print( "Qué divertido!" )

# %%
# realiza la pregunta
activity = input( "Qué te gusta hacer en tus tardes libres?\n(A) Leer un libro\n(B) Ir a alguna fiesta\n" )

# print out which activity they chose
print( f"Eligiste {activity}.")

if activity == "A":
    print( "Es una buena opción!" )
else:
    print( "Qué divertido!" )

# %%
print("\t\t\t+-+-+-+-+-+-+-+-+-+-+\n\t\t\t|B|i|e|n|v|e|n|i|d|o|\n\t\t\t+-+-+-+-+-+-+-+-+-+-+\n")
# realiza la pregunta
activity = input( "Qué te gusta hacer en tus tardes libres?\n(A) Leer un libro\n(B) Ir a alguna fiesta\n" )

# print out which activity they chose
print( f"Eligiste {activity}.")

if activity == "A":
    print( "Es una buena opción!" )
elif activity == "B":
    print( "Qué divertido!" )
else:
    print("Debes escribir A o B. Bueno, supongamos que elegiste A.")

# %%
# realiza la primer pregunta
activity = input( "Qué te gusta hacer en tus tardes libres?\n(A) Leer un libro\n(B) Ir a alguna fiesta\n" )

if activity == "A":
    print( "Es una buena opción!" )
elif activity == "B":
    print( "Qué divertido!" )
else:
    print("Debes escribir A o B. Bueno, supongamos que elegiste A.")
    activity = 'A'

# realiza la segunda pregunta
job = input( "Dónde es tu sueño trabajar?\n(A) En algún lugar del Caribe\n(B) En la Ciudad de México\n" )
if job == "A":
    print( "En el Caribe! Genial!" )
elif job =="B":
    print( "En la Ciudad??? No suena divertido!" )
else:
    print("Debes escribir A o B. Bueno, supongamos que elegiste A.")
    job = "A"

# realiza la tercer pregunta
decade = input( "Cuál es tu década favorita?\n(A) 1910s\n(B) 2010s\n" )
if decade == "A":
    print( "1910s, buena elección!" )
elif decade =="B":
    print( "2010s? Mmmm!" )
else:
    print("Debes escribir A o B. Bueno, supongamos que elegiste A.")
    decade = "A"

# realiza la cuarta question
travel = input( "Cómo prefieres viajar?\n(A) Me gusta manejar en carretera\n(B) Prefiero tomar un avión\n" )
if travel == "A":
    print( "Te gusta manejar!" )
elif travel =="B":
    print( "Volando, suena bien" )
else:
    print("Debes escribir A o B. Bueno, supongamos que elegiste A.")
    travel = "A"

# print out their choices
print( f"Tu elegiste {activity}, entonces {job}, entonces {decade}, entonces {travel}.")

# %% [markdown]
# **Reto**  💪
#
# Crea un algoritmo para encontrar los valores en tu cuestionario. Inicialia variables de inicio y aumenta sus valores dependiendo de las opciones que el usuario elija.
# Utiliza nuevamente los condicionales.
